# %% [markdown]
# # Cargar los datos

# %%
# Importar las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %% [markdown]
# | **Nombre de la Columna** | **Descripción** |
# |--------------------------|-----------------|
# | `PassengerId`   | ID único para cada pasajero. |
# | `Survived`      | Supervivencia (0 = No, 1 = Sí). |
# | `Pclass`        | Clase del billete (1 = 1ra clase, 2 = 2da clase, 3 = 3ra clase). |
# | `Name`          | Nombre del pasajero. |
# | `Sex`           | Género del pasajero (male = hombre, female = mujer). |
# | `Age`           | Edad del pasajero en años. |
# | `SibSp`         | Número de hermanos/esposos a bordo del Titanic. |
# | `Parch`         | Número de padres/hijos a bordo del Titanic. |
# | `Ticket`        | Número del billete. |
# | `Fare`          | Tarifa pagada por el billete. |
# | `Cabin`         | Número de cabina. |
# | `Embarked`      | Puerto de embarque (C = Cherburgo, Q = Queenstown, S = Southampton). |

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 489          490         1       3  Coutts, Master. Eden Leslie "Neville"
# 629          630         0       3               O'Connell, Mr. Patrick D
# 601          602         0       3                   Slabenoff, Mr. Petco
# 266          267         0       3              Panula, Mr. Ernesti Arvid
# 789          790         0       1               Guggenheim, Mr. Benjamin
#
#       Sex   Age  SibSp  Parch      Ticket     Fare    Cabin Embarked
# 489  male   9.0      1      1  C.A. 37671  15.9000      NaN        S
# 629  male   NaN      0      0      334912   7.7333      NaN        Q
# 601  male   NaN      0      0      349214   7.8958      NaN        S
# 266  male  16.0      4      1     3101295  39.6875      NaN        S
# 789  male  46.0      0      0    PC 17593  79.2000  B82 B84        C

# %% [markdown]
# # Análisis Exploratorio de Datos
# (Omitido aquí porque lo hicimos la vez pasada)

# %% [markdown]
# # Dividir datos en entrenamiento (train) y prueba (test)
#
# Es necesario separar los datos en datos de entrenamiento y prueba antes de realizar cualquier ingeniería de características

# %%
# Definir las características (X) y la variable objetivo (y)
X = df.drop(columns=['Survived'])  # Aquí estamos eliminando la columna 'survived', que es el objetivo
y = df['Survived']  # Esta es nuestra variable objetivo

# %%
X.sample()
# Out:
#      PassengerId  Pclass                      Name     Sex   Age  SibSp  \
# 318          319       1  Wick, Miss. Mary Natalie  female  31.0      0
#
#      Parch Ticket      Fare Cabin Embarked
# 318      2  36928  164.8667    C7        S

# %%
y.sample()
# Out:
# 216    1
# Name: Survived, dtype: int64

# %%
# Dividir el conjunto de datos en entrenamiento (train) y prueba (test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.sample()
# Out:
#      PassengerId  Pclass                                          Name  \
# 849          850       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
#
#         Sex  Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 849  female  NaN      1      0  17453  89.1042   C92        C

# %%
X_test.sample()
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch  \
# 847          848       3  Markoff, Mr. Marin  male  35.0      0      0
#
#      Ticket    Fare Cabin Embarked
# 847  349213  7.8958   NaN        C

# %%
y_train.sample()
# Out:
# 842    1
# Name: Survived, dtype: int64

# %%
y_test.sample()
# Out:
# 442    0
# Name: Survived, dtype: int64

# %%
# Ver el tamaño de los conjuntos
print(f"Tamaño del conjunto de entrenamiento: {X_train.shape}. Tamaño de las etiquetas de entrenamiento: {y_train.shape}")
print(f"Tamaño del conjunto de prueba: {X_test.shape}. Tamaño de las etiquetas de prueba: {y_test.shape}")
# Out:
# Tamaño del conjunto de entrenamiento: (712, 11). Tamaño de las etiquetas de entrenamiento: (712,)
# Tamaño del conjunto de prueba: (179, 11). Tamaño de las etiquetas de prueba: (179,)

# %% [markdown]
# # Ingeniería de características

# %%
X_train.head()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 864          865       2        Gill, Mr. John William    male  24.0      0
# 66            67       2  Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 467          468       1    Smart, Mr. John Montgomery    male  56.0      0
# 364          365       3           O'Brien, Mr. Thomas    male   NaN      1
# 484          485       1       Bishop, Mr. Dickinson H    male  25.0      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 864      0      233866  13.0000   NaN        S
# 66       0  C.A. 29395  10.5000   F33        S
# 467      0      113792  26.5500   NaN        S
# 364      0      370365  15.5000   NaN        Q
# 484      0       11967  91.0792   B49        C

# %%
# One-Hot Encoding para las columnas 'Sex' y 'Embarked'
X_train = pd.get_dummies(X_train, columns=['Sex', 'Embarked'], drop_first=True)

# %%
X_train.head()
# Out:
#      PassengerId  Pclass                          Name   Age  SibSp  Parch  \
# 864          865       2        Gill, Mr. John William  24.0      0      0
# 66            67       2  Nye, Mrs. (Elizabeth Ramell)  29.0      0      0
# 467          468       1    Smart, Mr. John Montgomery  56.0      0      0
# 364          365       3           O'Brien, Mr. Thomas   NaN      1      0
# 484          485       1       Bishop, Mr. Dickinson H  25.0      1      0
#
#          Ticket     Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 864      233866  13.0000   NaN      True       False        True
# 66   C.A. 29395  10.5000   F33     False       False        True
# 467      113792  26.5500   NaN      True       False        True
# 364      370365  15.5000   NaN      True        True       False
# 484       11967  91.0792   B49      True       False       False

# %%
# Rellenar los valores faltantes de 'Age' con la mediana
X_train['Age'].fillna(X_train['Age'].median(), inplace=True)

# %%
X_train.head()
# Out:
#      PassengerId  Pclass                          Name   Age  SibSp  Parch  \
# 864          865       2        Gill, Mr. John William  24.0      0      0
# 66            67       2  Nye, Mrs. (Elizabeth Ramell)  29.0      0      0
# 467          468       1    Smart, Mr. John Montgomery  56.0      0      0
# 364          365       3           O'Brien, Mr. Thomas  28.0      1      0
# 484          485       1       Bishop, Mr. Dickinson H  25.0      1      0
#
#          Ticket     Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 864      233866  13.0000   NaN      True       False        True
# 66   C.A. 29395  10.5000   F33     False       False        True
# 467      113792  26.5500   NaN      True       False        True
# 364      370365  15.5000   NaN      True        True       False
# 484       11967  91.0792   B49      True       False       False

# %%
# Crear un MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(X_train[['Age', 'Fare']])
# Out:
# MinMaxScaler()

# %%
# Ver los mínimos y máximos aprendidos por el scaler
print("Mínimos aprendidos por el scaler:", scaler.data_min_)
print("Máximos aprendidos por el scaler:", scaler.data_max_)
# Out:
# Mínimos aprendidos por el scaler: [0.42 0.  ]
# Máximos aprendidos por el scaler: [ 80.     512.3292]

# %%
# Aplicar el escalado solo en las columnas 'Age' y 'Fare'
X_train[['Age', 'Fare']] = scaler.transform(X_train[['Age', 'Fare']])

# %%
X_train.head()
# Out:
#      PassengerId  Pclass                          Name       Age  SibSp  \
# 864          865       2        Gill, Mr. John William  0.296306      0
# 66            67       2  Nye, Mrs. (Elizabeth Ramell)  0.359135      0
# 467          468       1    Smart, Mr. John Montgomery  0.698417      0
# 364          365       3           O'Brien, Mr. Thomas  0.346569      1
# 484          485       1       Bishop, Mr. Dickinson H  0.308872      1
#
#      Parch      Ticket      Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 864      0      233866  0.025374   NaN      True       False        True
# 66       0  C.A. 29395  0.020495   F33     False       False        True
# 467      0      113792  0.051822   NaN      True       False        True
# 364      0      370365  0.030254   NaN      True        True       False
# 484      0       11967  0.177775   B49      True       False       False

# %%
# Extraer la primera letra de la cabina
X_train['Letra_Cabina'] = X_train['Cabin'].str[0]

# %%
X_train['Letra_Cabina'].fillna('Unknown', inplace=True)

# %%
X_train.Letra_Cabina.value_counts()
# Out:
# Letra_Cabina
# Unknown    556
# C           42
# B           38
# E           25
# D           21
# A           14
# F           11
# G            4
# T            1
# Name: count, dtype: int64

# %%
# One-Hot Encoding para la columna Letra_Cabina
X_train = pd.get_dummies(X_train, columns=['Letra_Cabina'], drop_first=True)

# %%
X_train.head()
# Out:
#      PassengerId  Pclass                          Name       Age  SibSp  \
# 864          865       2        Gill, Mr. John William  0.296306      0
# 66            67       2  Nye, Mrs. (Elizabeth Ramell)  0.359135      0
# 467          468       1    Smart, Mr. John Montgomery  0.698417      0
# 364          365       3           O'Brien, Mr. Thomas  0.346569      1
# 484          485       1       Bishop, Mr. Dickinson H  0.308872      1
#
#      Parch      Ticket      Fare Cabin  Sex_male  Embarked_Q  Embarked_S  \
# 864      0      233866  0.025374   NaN      True       False        True
# 66       0  C.A. 29395  0.020495   F33     False       False        True
# 467      0      113792  0.051822   NaN      True       False        True
# 364      0      370365  0.030254   NaN      True        True       False
# 484      0       11967  0.177775   B49      True       False       False
#
#      Letra_Cabina_B  Letra_Cabina_C  Letra_Cabina_D  Letra_Cabina_E  \
# 864           False           False           False           False
# 66            False           False           False           False
# 467           False           False           False           False
# 364           False           False           False           False
# 484            True           False           False           False
#
#      Letra_Cabina_F  Letra_Cabina_G  Letra_Cabina_T  Letra_Cabina_Unknown
# 864           False           False           False                  True
# 66             True           False           False                 False
# 467           False           False           False                  True
# 364           False           False           False                  True
# 484           False           False           False                 False

# %%
# Resultado para ser entrenado
X_train.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Sex_male', 'Embarked_Q', 'Embarked_S',
#        'Letra_Cabina_B', 'Letra_Cabina_C', 'Letra_Cabina_D', 'Letra_Cabina_E',
#        'Letra_Cabina_F', 'Letra_Cabina_G', 'Letra_Cabina_T',
#        'Letra_Cabina_Unknown'],
#       dtype='object')

# %%
X_train = X_train[['Pclass', 'Age', 'SibSp', 'Parch',
       'Fare', 'Sex_male', 'Embarked_Q', 'Embarked_S',
       'Letra_Cabina_B', 'Letra_Cabina_C', 'Letra_Cabina_D', 'Letra_Cabina_E',
       'Letra_Cabina_F', 'Letra_Cabina_G', 'Letra_Cabina_T',
       'Letra_Cabina_Unknown']]

# %%
X_train.head()
# Out:
#      Pclass       Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  \
# 864       2  0.296306      0      0  0.025374      True       False
# 66        2  0.359135      0      0  0.020495     False       False
# 467       1  0.698417      0      0  0.051822      True       False
# 364       3  0.346569      1      0  0.030254      True        True
# 484       1  0.308872      1      0  0.177775      True       False
#
#      Embarked_S  Letra_Cabina_B  Letra_Cabina_C  Letra_Cabina_D  \
# 864        True           False           False           False
# 66         True           False           False           False
# 467        True           False           False           False
# 364       False           False           False           False
# 484       False            True           False           False
#
#      Letra_Cabina_E  Letra_Cabina_F  Letra_Cabina_G  Letra_Cabina_T  \
# 864           False           False           False           False
# 66            False            True           False           False
# 467           False           False           False           False
# 364           False           False           False           False
# 484           False           False           False           False
#
#      Letra_Cabina_Unknown
# 864                  True
# 66                  False
# 467                  True
# 364                  True
# 484                 False
